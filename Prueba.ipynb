# %% [markdown]
# <a href="https://colab.research.google.com/github/SAMPAYOVILLALBA/EDP1/blob/main/Prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-10, 10, 400)
y = x**2

plt.plot(x, y, label="y = x²", color="blue")


plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gráfica de y = x²")
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-10, 10, 400)
y = x**2


plt.plot(x, y, label="y = x²", color="blue")

plt.axhline(0, color="black", linewidth=1)
plt.axvline(0, color="black", linewidth=1)
plt.grid(True, linestyle="--", alpha=0.6)
plt.legend()
plt.xlabel("x")
plt.ylabel("y")
plt.title("Gráfica de y = x²")


plt.show()
