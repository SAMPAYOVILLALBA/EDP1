# %%
from sympy import *

# %% [markdown]
# La libreria **sympy** permite realizar cálculos matemáticos simbólicos, es decir, con símbolos en lugar de con valores numéricos.

# %%
x=symbols('x')
x**2+5
# Out:
# x**2 + 5

# %% [markdown]
# Notamos que definimos a "x" como un simbolo o una variable

# %%
c1=plotting.plot(x*x)

# %% [markdown]
# La funcion .plot en python nos ayuda a generar graficos de la funcion dada forma mas sencilla que en otros programas.

# %%
cl=plotting.plot(x*x,show=False)32
c2=plotting.plot(x**3,show=False)

# %% [markdown]
# En esta celda el show=False indican que las graficas de las funciones plotting.plot se "guardan" en c1 y c2 y no se muestran de inmediato y se pueden cambiar parametros.

# %%
c1 #Indica qué es y en qué espacio de memoria está

# %%
c1.append(c2[0]) #Anida las gráficas sin los ejes

# %% [markdown]
# En esta celda el .append nos ayudara agregar un elemento al final de una lista

# %%
c1

# %%
c1.show()

# %% [markdown]
# <font color=red>La funcion show nos ayudara para mostrar las gráficas creadas con la biblioteca matplotlib. </font>

# %%
c1.extend(c2)

# %% [markdown]
# <font color=pink>La funcion extend sirve para agregar elementos al final de una lista</font>

# %%
c1.show()

# %% [markdown]
# <font color=blue>La funcion show nos ayudara para mostrar las gráficas creadas con la biblioteca matplotlib. </font>

# %%
c2.show()

# %% [markdown]
# <font color=green>La funcion show nos ayudara para mostrar las gráficas creadas con la biblioteca matplotlib. </font>

# %% [markdown]
# La funcion show nos ayudara para mostrar las gráficas creadas con la biblioteca matplotlib.

# %%
from sympy.plotting import plot

# %%
plot(x**2)

# %% [markdown]
# Grafica la funcion x**2 en un rango determinado

# %%
plot(x**2,(x,-1,1))

# %% [markdown]
# Grafica la funcion x**2 en el intervalo de -1 a 1

# %%
plot(exp(x))
#plot(exp(x),(x,0,2))

# %% [markdown]
# Aqui grafica la funcion exponencial

# %%
plot(x,x**2,x**3, (x,-2,2))

# %% [markdown]
# En esta celda grafica 3 funciones $$x,x^2, x^3$$ Ademas de estar en el intervalo de -2 a 2

# %%
plot(x**2,adaptative=False,nb_of_points=10) #Revisar

# %% [markdown]
# Graficaca la funcion $$x^2$$ y que solo se grafiquen 10 puntos

# %% [markdown]
# ### Curvas parametrizadas

# %% [markdown]
# Importar la funcion plot de la biblioteca sympy para graficar las curvas parametrizadas

# %%
from sympy import plot_parametric

# %% [markdown]
# Define la variable y

# %%
s=symbols('s')

# %%
plot_parametric((cos(s)),sin(s))

# %%
plot_parametric((cos(s),sin(s)),(s,s**2),(s,-4,4))

# %%
c2[0].line_color='green'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-01329f47be38> in <cell line: 0>()
# ----> 1 c2[0].line_color='green'
#
# NameError: name 'c2' is not defined

# %%
c2.show()

# %% [markdown]
# ### Graficas 3D

# %%
from sympy.plotting import plot3d

# %%
x,y=symbols('x y')

# %%
plot3d(x*y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-13745969ebba> in <cell line: 0>()
# ----> 1 plot3d(x*y)
#
# NameError: name 'plot3d' is not defined

# %%
plot3d(x*y, (x,-5,5),(y,-5,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-21defc9845af> in <cell line: 0>()
# ----> 1 plot3d(x*y, (x,-5,5),(y,-5,5))
#
# NameError: name 'plot3d' is not defined

# %%
plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-de12a6d86f27> in <cell line: 0>()
# ----> 1 plot3d(x*y, -x*y, (x,-5,5),(y,-5,5))
#
# NameError: name 'plot3d' is not defined

# %%
plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-e8ec9c7be17c> in <cell line: 0>()
# ----> 1 plot3d((x**2 + y**2, (x,-5,5),(y,-5,5)),(x*y,(x,-3,3),(y,-3,3)))
#
# NameError: name 'plot3d' is not defined

# %%
from sympy.plotting import plot3d_parametric_line

# %%
plot3d_parametric_line(cos(s),sin(s),s)

# %%
plot3d_parametric_line((cos(s),sin(s),s,(s,-5,5)),(sin(s),s**2,s,(s,-5,5)))

# %%
from sympy.plotting import plot3d_parametric_surface

# %%
u, v =symbols('u v')

# %%
plot3d_parametric_surface(cos(u+v),sin(u-v),u-v)

# %%
plot3d_parametric_surface(cos(v)*cos(u),cos(v)*sin(u),sin(v))

# %% [markdown]
# Funciones implícitas

# %%
from sympy import plot_implicit, symbols, Eq, And

# %%
x, y = symbols(' x y')

# %%
p1 = plot_implicit(Eq(x**2 + y**2, 5))

# %%
p6 = plot_implicit(y > x**2)

# %%
p6 = plot_implicit(And(y > x, y > -x))

# %% [markdown]
# Funcion $$T=x^3-xy+y^3$$
# No mme grafica y mi funcion esta bien

# %%
plot3d(x**3-x*y+y**3,(x,-3,3),(y,2,2))
